# %% [markdown]
# # Cuidado com o while -> Loop Infinito
#
# Sempre que for usar o comando while, lembre-se de ter certeza que o programa vai terminar em algum momento
#
# ### Exemplo
#
# Digamos que temos uma lista de vendedores e as quantidades vendidas e queremos identificar todos os vendedores que bateram a meta de 50 vendas.

# %%
vendas = [941, 852, 783, 714, 697, 686, 685, 670, 631, 453, 386, 371, 294, 269, 259, 218, 208, 163, 125, 102, 87, 47, 7]
vendedores = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']
meta = 50

i = 0 

while vendas[i] > meta:
    print(f'{vendedores[i]} bateu a meta. Vendas: {vendedores[i]}')

    # Diferente do for, o While não incrementa automaticamente i de acordo com algo como uma lista. Então é necessario que seu While tenha algo que realize isso a cada looping.

    i += 1
# Out:
# Maria bateu a meta. Vendas: Maria
# José bateu a meta. Vendas: José
# Antônio bateu a meta. Vendas: Antônio
# João bateu a meta. Vendas: João
# Francisco bateu a meta. Vendas: Francisco
# Ana bateu a meta. Vendas: Ana
# Luiz bateu a meta. Vendas: Luiz
# Paulo bateu a meta. Vendas: Paulo
# Carlos bateu a meta. Vendas: Carlos
# Manoel bateu a meta. Vendas: Manoel
# Pedro bateu a meta. Vendas: Pedro
# Francisca bateu a meta. Vendas: Francisca
# Marcos bateu a meta. Vendas: Marcos
# Raimundo bateu a meta. Vendas: Raimundo
# Sebastião bateu a meta. Vendas: Sebastião
# Antônia bateu a meta. Vendas: Antônia
# Marcelo bateu a meta. Vendas: Marcelo
# Jorge bateu a meta. Vendas: Jorge
# Márcia bateu a meta. Vendas: Márcia
# Geraldo bateu a meta. Vendas: Geraldo
# Adriana bateu a meta. Vendas: Adriana
