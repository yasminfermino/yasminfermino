# %% [markdown]
# # Exercícios
#
# ## 1. Calculando % de uma lista
#
# Faremos algo parecido com "filtrar" uma lista. Mais pra frente no curso aprenderemos outras formas de fazer isso, mas com o nosso conhecimentoa atual já conseguimos resolver o desafio.
#
# Digamos que a gente tenha uma lista de vendedores e ao invés de saber todos os vendedores que bateram a meta, eu quero conseguir calcular o % de vendedores que bateram a meta. Ou seja, se temos 10 vendedores e 3 bateram a meta, temos 30% dos vendedores que bateram a meta.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Luana', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
#seu código aqui

x = 0
y = 0

for lista in vendas:
    y = y+1
    if lista[1] >= meta:
        x= x+1
    else:
        pass

result = (x * 100)/(y)
print(f'{result:.2f} %')
# Out:
# 50.00 %

# %%
# 1. forma do exercicio - lista auxiliar 

acima_meta = []

for item in vendas:
    if item[1] >= meta:
        acima_meta.append(item)
    else:
        pass

print('{:.0%} dos vendedores bateram a meta'.format (len(acima_meta)/len(vendas)))
# Out:
# 50% dos vendedores bateram a meta

# %%
# 2. calc diretamente na lista que temos

qtd_vend_acima = 0

for venda in vendas:
    if venda[1] >= meta:
        qtd_vend_acima += 1
    else:
        pass

print('{:.1%} dos vendedores bateram a meta'.format (qtd_vend_acima/len(vendas)))
# Out:
# 50.0% dos vendedores bateram a meta

# %% [markdown]
# - Vamos resolver de 2 formas:
#     1. Criando uma lista auxiliar apenas com os vendedores que bateram a meta
#     2. Fazendo o cálculo diretamente na lista que já temos

# %% [markdown]
# ## Para treinar uma estrutura parecida, crie um código para responder: quem foi o vendedor que mais vendeu?

# %%
#seu código aqui

maior_valor_venda = 0

melhor_vendedor = ''

for vendai in vendas:
        if vendai[1] > maior_valor_venda:
            maior_valor_venda = vendai[1]
            melhor_vendedor = vendai[0]
        else:
            pass
    
print (f'O melhor vendedor foi {melhor_vendedor}, com o total de {maior_valor_venda} Reais em vendas')
# Out:
# O melhor vendedor foi Luana, com o total de 27000 Reais em vendas
