# %% [markdown]
# # Formas de interromper um for
#
# ### 2 Opções:
#
# - break -> interrompe e finaliza o for
# - continue -> interrompe e vai para o próximo item do for

# %%
vendas = [100, 150, 1500, 2000, 120]

# %% [markdown]
# - Caso 1: Se todas as vendas forem acima da meta, a loja ganha bônus

# %%
meta = 110

for venda in vendas:
    if venda < meta:
        print ('Loja não ganha bonus')
        break
    else:
        print('Loja ganha venda')
# Out:
# Loja não ganha bonus

# %% [markdown]
# - Caso 2: Exiba quem bateu a meta

# %%
vendedores = ['João', 'Luana', 'Ana', 'José', 'Maria']
meta = 130

# %%
for i, venda in enumerate(vendas):
    if venda < meta:
        continue
    print (f'O {vendedores[i]} vendeu {venda} Reais')
# Out:
# O Luana vendeu 150 Reais
# O Ana vendeu 1500 Reais
# O José vendeu 2000 Reais
