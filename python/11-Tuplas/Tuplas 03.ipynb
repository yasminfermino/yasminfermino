# %% [markdown]
# # Aplicação de Tupla - Lista de Tuplas
#
# ### Estrutura:
#
# Além de casos como o do enumerate, em que usamos uma função para transformar itens em tuplas porque isso ajuda o nosso código, temos também listas de tuplas como algo comum dentro do Python.

# %% [raw]
# lista = [
#     tupla1,
#     tupla2,
#     tupla3,
#     ]
#
# ou seja
#
# lista = [
#     (valor1, valor2, valor3),
#     (valor4, valor5, valor6),
#     (valor7, valor8, valor9),
#     ]

# %% [markdown]
# ### Exemplo:
#
# Digamos que você está analisando as vendas do Banco de Dados de um e-commerce.
#
# Em um determinado dia, você extraiu as vendas do Banco de Dados e elas vieram nesse formato:

# %%
vendas = [
    ('20/08/2020', 'iphone x', 'azul', '128gb', 350, 4000),
    ('20/08/2020', 'iphone x', 'prata', '128gb', 1500, 4000),
    ('20/08/2020', 'ipad', 'prata', '256gb', 127, 6000),
    ('20/08/2020', 'ipad', 'prata', '128gb', 981, 5000),
    ('21/08/2020', 'iphone x', 'azul', '128gb', 397, 4000),
    ('21/08/2020', 'iphone x', 'prata', '128gb', 1017, 4000),
    ('21/08/2020', 'ipad', 'prata', '256gb', 50, 6000),
    ('21/08/2020', 'ipad', 'prata', '128gb', 4000, 5000),
]

# %% [markdown]
# - Qual foi o faturamento de IPhone no dia 20/08/2020?
# - Qual foi o produto mais vendido (em unidades) no dia 21/08/2020?

# %%
data, produto, cor, capacidade, unids, valor_unit = vendas[0]

fatu = unids * valor_unit
print(fatu)
# Out:
# 1400000

# %%
# Qual foi o faturamento de iphone no dia 20/08/2020

for item in vendas:
    datadata, produto, cor, capacidade, unids, valor_unit = item

    if produto == 'iphone x' and  data == '20/08/2020':
        fatu += unids * valor_unit
        
print(fatu)
# Out:
# 27512000

# %%
# Qual foi o produto mais vendido (em unidades) no dia 21/08/2020?

produtomaisvendido = ''
qtdprodmaisvendido = 0

for item in vendas:
    data, produto, cor, capacidade, unids, valor_unit = item

    if data == '21/08/2020' and qtdprodmaisvendido < unids:
        produtomaisvendido = produto
        qtdprodmaisvendido = unids

print (f'Produto mais vendido na data de 21/08/2020 é {produtomaisvendido}, com {qtdprodmaisvendido} unidades vendidas.')
# Out:
# Produto mais vendido na data de 21/08/2020 é ipad, com 4000 unidades vendidas.
